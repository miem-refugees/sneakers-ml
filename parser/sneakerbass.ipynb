# %%
from bs4 import BeautifulSoup
import requests
from fake_useragent import UserAgent
from urllib.parse import urlparse, urlunparse
from urllib.parse import urlsplit
import re
import os

ua = UserAgent()
headers = {"User-Agent": ua.random}


def get_home_link(url):
    parsed_url = urlsplit(url)
    home_link = f"{parsed_url.scheme}://{parsed_url.netloc}"
    return home_link


def remove_query_from_url(url):
    parsed_url = urlparse(url)
    parsed_url = parsed_url._replace(query="")
    modified_url = urlunparse(parsed_url)
    return modified_url


def add_https_to_url(url):
    if not url.startswith("http://") and not url.startswith("https://"):
        corrected_url = "https://" + url
    else:
        corrected_url = url
    return corrected_url


def get_image_extension(url):
    parsed_url = urlparse(url)
    parsed_url = urlparse(
        add_https_to_url(
            "www.sneakerbaas.com/cdn/shop/files/SH_D1GA330906_03_2000x2000.png"
        )
    )
    return "." + parsed_url.path.split("/")[-1].split(".")[1]


WEBSITE_NAME = "sneakerbaas"

# %%
link = "https://www.sneakerbaas.com/collections/men"
# link = "https://www.sneakerbaas.com/collections/sneakers"

# %%
def get_website_info(link):
    r = requests.get(link, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")
    products_string = soup.find_all(class_=re.compile("collection-size"))[
        0
    ].text.strip()
    products_number = int(re.search(r"\d+", products_string).group())
    number_of_pages = int(
        soup.find_all(class_=re.compile("(?<!\S)pagination(?!\S)"))[0]
        .find_all("span")[-2]
        .a.text
    )
    return {"products_number": products_number, "number_of_pages": number_of_pages}

# %%
get_website_info(link)
# Out:
# {'products_number': 399, 'number_of_pages': 10}

# %%
def get_sneakers_links(link):
    r = requests.get(link, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")
    home_link = get_home_link(link)
    sneakers_links = set(
        [
            home_link + item["href"]
            for item in soup.find_all(href=re.compile("/collections/men/products"))
        ]
    )
    return {"sneakers_links": sneakers_links, "number_of_links": len(sneakers_links)}

# %%
def get_metadata_photos(url):
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")

    # metadata
    metadata_keys = ["brand","description","priceCurrency", "price"]
    meta_html = soup.find_all(name="div",class_="page-row-content")[0].div.find_all(name="meta")
    print(meta_html)
    temp = {}
    for meta in meta_html:
        if meta.has_attr("itemprop" ):
            if meta["itemprop"] in metadata_keys:
                temp[meta["itemprop"]] = meta["content"].replace('\xa0', ' ')
    

    default_fields = ["Description", "Colors", "Stijlcode"]
    for i, item in enumerate(temp["description"].split("- ")[1:]):
        temp[default_fields[i]] = item
    temp.pop("description")

    # title
    temp["title"] = soup.find(name="main",id="MainContent").find_all(name="span")[2].text

    # images
    for i,product_image in enumerate(soup.find_all(name="div", class_="swiper-slide product-image")):
        image_link = add_https_to_url(remove_query_from_url(product_image.find("a",{'data-fancybox': 'productGallery'})["href"][2:]))
        img_binary = requests.get(image_link).content
        os.makedirs(os.path.join("parser",WEBSITE_NAME, temp["brand"],temp["title"]), exist_ok=True)
        with open(os.path.join("parser",WEBSITE_NAME,temp["brand"], temp["title"], str(i)+ get_image_extension(image_link)), "wb") as f:
            f.write(img_binary)

    temp["photos_path"] = os.path.join("parser",WEBSITE_NAME,temp["title"])

    return temp

# %%
page_link = f"https://www.sneakerbaas.com/collections/men?page={2}"
temp = get_sneakers_links(page_link)
sneakers_links = temp["sneakers_links"]
number_of_links = temp["number_of_links"]
print(f"{number_of_links} кроссовок на странице")
# Out:
# 44 кроссовок на странице

# %%
full_metadata = []
for sneakers_link in sneakers_links:
    metadata = get_metadata_photos(sneakers_link)
    full_metadata.append(metadata)
# Out:
# [<meta 40"="" content="Shaq Attaq " gold"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/shaq-attaq-ftwwht-cblack-goldmt?variant=46877002563910" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/0920095456_650a42e0051cb_600x600.png?v=1695885843" itemprop="image"/>, <meta content='- Reebok SHAQ ATTAQ "FTWWHT/CBLACK/GOLDMT"- Colour: Black / White / Gold- Stijlcode: 100032830' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="179.95" itemprop="price"/>]
# [<meta 42"="" black"-="" content="Shadow 6000 " itemprop="name" purple=""/>, <meta content="https://www.sneakerbaas.com/products/shadow-6000-purple-black?variant=47077545247046" itemprop="url"/>, <meta content="Saucony" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_205_fe054b19-8b5e-4fd2-bd0c-fb2550f5de2c_600x600.png?v=1691480471" itemprop="image"/>, <meta content='- Saucony Shadow 6000 "Purple / Black"- Colour: Purple / Coral / Black- Stijlcode: S70784-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="154.95" itemprop="price"/>]
# [<meta 40"="" content="Pump TZ " itemprop="name" neon"-=""/>, <meta content="https://www.sneakerbaas.com/products/pump-tz-ftwwht-cblack-soacye?variant=46876995551558" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_411_600x600.png?v=1694616119" itemprop="image"/>, <meta content='- Reebok PUMP TZ "FTWWHT/CBLACK/SOACYE"- Colour: White / Black / Neon- Stijlcode: 100033132' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="159.95" itemprop="price"/>]
# [<meta 41"="" content="Wallabee Eden " dark="" itemprop="name" sand"-=""/>, <meta content="https://www.sneakerbaas.com/products/wallabee-eden-dark-sand?variant=48499926106438" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/edenbeige_600x600.jpg?v=1694090002" itemprop="image"/>, <meta content='- Clarks Wallabee Eden "Dark Sand"- Beige / Cream- Stijlcode: 26173319' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="269.95" itemprop="price"/>]
# [<meta 40"="" content="Medalist Low M " itemprop="name" malachi"-=""/>, <meta content="https://www.sneakerbaas.com/products/medalist-low-m-leat-wht-malachi?variant=46818940748102" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/AULMWB30_a6d2765a-8101-4f5b-8992-87ceb1be7ba8_600x600.jpg?v=1690364179" itemprop="image"/>, <meta content='- Autry Medalist Low M "Leat Wht/Malachi"- Colour: Mint / White / Cream- Stijlcode: AULMWB30' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="179.95" itemprop="price"/>]
# [<meta 46"="" blue"-="" content="CLC Low M " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/clc-low-m-mat-wht-pbl?variant=46818937667910" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/ROLMMM06_39f73f8d-ccd4-4ead-b44b-a17c9ed943cf_600x600.jpg?v=1690364420" itemprop="image"/>, <meta content='- Autry CLC Low M "Mat Wht/Pbl"- Colour: White / Blue- Stijlcode: ROLMMM06' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta content="Grid Shadow 2 OG- 40" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/grid-shadow-2-og-blue-white?variant=47013909889350" itemprop="url"/>, <meta content="Saucony" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/S70772-1_1_491766cc-a6a7-4905-a43f-e27c9268053f_600x600.png?v=1691481050" itemprop="image"/>, <meta content='- Saucony Grid Shadow 2 OG "Blue / White"- Colour: White / Blue / Black- Stijlcode: S70772-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="109.95" itemprop="price"/>]
# [<meta content="Grid Shadow 2- 41" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/grid-shadow-2-green-tan?variant=48220458844486" itemprop="url"/>, <meta content="Saucony" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/S70782-1_600x600.png?v=1693409208" itemprop="image"/>, <meta content='- Saucony Grid Shadow 2 "Creek Marsh"- Colour: Green / Blue / White- Stijlcode: S70782-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="129.95" itemprop="price"/>]
# [<meta 40.5"="" content="Slipstream Xtreme " itemprop="name" yellow"-=""/>, <meta content="https://www.sneakerbaas.com/products/slipstream-xtreme-color-yellow-sizzle?variant=48478563107142" itemprop="url"/>, <meta content="PUMA Sportstyle" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_309_36c8c152-789b-4f97-978e-8ba7b62491a0_600x600.png?v=1693484679" itemprop="image"/>, <meta content='- Puma Slipstream Xtreme Color "Yellow Sizzle"- Colour: White / Green / Yellow- Stijlcode: 394695-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" content="Shadow 5000 " forest"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/shadow-5000-forest?variant=48496270704966" itemprop="url"/>, <meta content="Saucony Originals" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/S70778-1_1_fa9a023c-a301-4e63-8f75-ac042b60b708_600x600.png?v=1694438541" itemprop="image"/>, <meta content='- Saucony Shadow 5000 "Forest"- Colour: Green / Cream / White- Stijlcode: S70778-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="144.95" itemprop="price"/>]
# [<meta 44"="" content="CLC Low M " itemprop="name" violet"-=""/>, <meta content="https://www.sneakerbaas.com/products/clc-low-m-mat-wht-vi-or?variant=46818939404614" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/ROLMMM08_5771c3c7-3a5d-4e26-8681-07fe61c6ded2_600x600.jpg?v=1690364287" itemprop="image"/>, <meta content='- Autry CLC Low M "Mat Wht/Vi/Or"- Colour: Cream / Purple / Orange- Stijlcode: ROLMMM08' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta 41"="" black="" content="Weaver " itemprop="name" suede"-=""/>, <meta content="https://www.sneakerbaas.com/products/weaver-black-suede?variant=48499921486150" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/weaver_97f612b3-f0a2-4dc0-a3f7-946f3061aa85_600x600.jpg?v=1694439002" itemprop="image"/>, <meta content='- Clarks Weaver "Black Suede"- Colour: Black- Stijlcode: 26165081' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="169.95" itemprop="price"/>]
# [<meta 40"="" content="BB Court Lo " itemprop="name" red"-="" tibetan=""/>, <meta content="https://www.sneakerbaas.com/products/bb-court-lo-tibetan-red?variant=47090539659590" itemprop="url"/>, <meta content="Sergio Tacchini" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/tibetanred_023565e4-c3a7-41e2-80df-f04a6df55700_600x600.jpg?v=1692179039" itemprop="image"/>, <meta content='- Sergio Tacchini BB Court Lo "Tibetan Red"- Colour: White / Red / Cream- Stijlcode: TSTU0004L-3502' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" content="Shadow 5000 " itemprop="name" rust"-=""/>, <meta content="https://www.sneakerbaas.com/products/shadow-5000-rust?variant=48496271065414" itemprop="url"/>, <meta content="Saucony Originals" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/S70778-2_600x600.png?v=1694073703" itemprop="image"/>, <meta content='- Saucony Shadow 5000 "Rust"- Colour: Orange / Grey / White- Stijlcode: S70778-2' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="144.95" itemprop="price"/>]
# [<meta 40"="" content="CLC Low M " itemprop="name" red"-=""/>, <meta content="https://www.sneakerbaas.com/products/clc-low-m-mat-wht-rd?variant=46818938945862" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/ROLMMM12_2deb3cf7-f7fa-43fb-af5c-0de693490661_600x600.jpg?v=1690364682" itemprop="image"/>, <meta content='- Autry CLC Low M "Mat Wht/Rd"- Colour: White / Red- Stijlcode: ROLMMM12' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta 41"="" content="Wallabee Mid " green"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/wallabee-mid-green?variant=48499925614918" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/midgreen_600x600.jpg?v=1694089030" itemprop="image"/>, <meta content='- Clarks Wallabee Mid "Green"- Colour: Green- Stijlcode: 26173640' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="159.95" itemprop="price"/>]
# [<meta 41"="" content="Contender " itemprop="name" rgreen"-=""/>, <meta content="https://www.sneakerbaas.com/products/contenderu-rgreen?variant=48510655496518" itemprop="url"/>, <meta content="Mizuno" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/cont2_7c732cb1-1cc3-49ad-9470-4a6e63f81412_600x600.jpg?v=1694521609" itemprop="image"/>, <meta content='- Mizuno Contender(U) "Rgreen"- Colour: Green / White / Orange- Stijlcode: D1GA2369-03' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="149.95" itemprop="price"/>]
# [<meta 40"="" bttl"-="" content="Medalist Low M " itemprop="name" suede=""/>, <meta content="https://www.sneakerbaas.com/products/medalist-low-m-suede-bttl-blue?variant=46818940027206" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/AULMSS17_c5d31c6a-0c44-4d3b-b34e-3f94da3a1c40_600x600.jpg?v=1690364097" itemprop="image"/>, <meta content='- Autry Medalist Low M "Suede Bttl/Blue"- Colour: Green / Blue / Cream- Stijlcode: AULMSS17' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="184.95" itemprop="price"/>]
# [<meta 40.5"="" content="Slipstream Xtreme " dune"-="" itemprop="name" sand=""/>, <meta content="https://www.sneakerbaas.com/products/slipstream-xtreme-earth-sand-dune?variant=48478562812230" itemprop="url"/>, <meta content="PUMA Sportstyle" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/3_b9972559-32b4-4ba9-8d62-7ffd7b33857f_600x600.jpg?v=1693495852" itemprop="image"/>, <meta content='- Puma Slipstream Xtreme Earth "Sand Dune"- Colour: Grey / Beige- Stijlcode: 394696-1' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" cola"-="" content="Weaver " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/weaver-cola?variant=48499922960710" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/cola1_528ffd97-f33d-4500-9e00-bc2095d4095a_600x600.jpg?v=1694088656" itemprop="image"/>, <meta content='- Clarks Weaver "Cola"- Colour: Brown / Beige- Stijlcode: 26165082' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="169.95" itemprop="price"/>]
# [<meta 43.3"="" black"-="" content="Handball Spezial " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/handball-spezial-black-white?variant=46865128161606" itemprop="url"/>, <meta content="adidas Originals" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/speziallekeeee_600x600.jpg?v=1687358177" itemprop="image"/>, <meta content='- adidas Originals Handball Spezial "Black / White"- Colour: Black / White- Stijlcode: DB3021' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="119.95" itemprop="price"/>]
# [<meta 41"="" beeswax"-="" content="Wallabee " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/wallabee-beeswax?variant=48499925451078" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/wallahibee_600x600.jpg?v=1694089289" itemprop="image"/>, <meta content='- Clarks Wallabee "Beeswax"- Colour: Brown / Cream- Stijlcode: 26156605' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="159.95" itemprop="price"/>]
# [<meta 41"="" content="Shadow 5000 " green"-="" grey="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/shadow-5000-grey-green-1?variant=48496263692614" itemprop="url"/>, <meta content="Saucony Originals" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_339_4f1b079e-8c15-49b1-be39-b6a0aa621095_600x600.png?v=1694438740" itemprop="image"/>, <meta content='- Saucony Shadow 5000 "Grey / Green"- Colour: Grey / Green / Pink- Stijlcode: S70779-2' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="144.95" itemprop="price"/>]
# [<meta 40.5"="" content="Legacy OG " itemprop="name" purple"-=""/>, <meta content="https://www.sneakerbaas.com/products/legacy-og-purple?variant=46898752848198" itemprop="url"/>, <meta content="Karhu" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermafbeelding2023-05-10om10.19.21_600x600.png?v=1687770521" itemprop="image"/>, <meta content='- Karhu Legacy OG "Purple"- Colour: White/Purple- Stylecode: F806001' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="69.99" itemprop="price"/>]
# [<meta 40.5"="" cashew"-="" content="Slipstream Xtreme Earth " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/slipstream-xtreme-earth-cashew?variant=48478566154566" itemprop="url"/>, <meta content="PUMA Sportstyle" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/1_d8318d36-3e30-4fbd-8c5c-bd1ded1c9e10_600x600.jpg?v=1693495548" itemprop="image"/>, <meta content='- Puma Slipstream Xtreme Earth "Cashew"- Colour: Beige / Green / Black- Stijlcode: 394696-2' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" content="Club C Bulc " itemprop="name" teayel"-=""/>, <meta content="https://www.sneakerbaas.com/products/club-c-bulc-cblack-cblack-teayel?variant=46876996370758" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_499_600x600.png?v=1695885626" itemprop="image"/>, <meta content='- Reebok CLUB C Bulc "CBLACK/CBLACK/TEAYEL"- Colour: Black / Yellow- Stijlcode: 100034265' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="119.95" itemprop="price"/>]
# [<meta 41"="" black"-="" content="Wallabee Eden " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/wallabee-eden-black?variant=48499921846598" itemprop="url"/>, <meta content="Clarks" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/edenblack_0a334a29-4dec-4a27-b54c-e6174d0fd464_600x600.jpg?v=1694089631" itemprop="image"/>, <meta content='- Clarks Wallabee Eden "Black"- Colour: Black / Cream- Stijlcode: 26173320' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="269.95" itemprop="price"/>]
# [<meta 43"="" content="Medalist Low " itemprop="name" syrah"-=""/>, <meta content="https://www.sneakerbaas.com/products/medalist-low-m-leat-wht-syrah?variant=46818940354886" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/AULMWB35_a3b40d7e-af4d-49ec-97e0-92be90c325d3_600x600.jpg?v=1690363802" itemprop="image"/>, <meta content='- Autry Medalist Low M "Leat Wht/Syrah"- Colour: Red / White- Stijlcode: AULMWB35' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="179.95" itemprop="price"/>]
# [<meta 41"="" black"-="" content="CLC Low M " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/clc-low-m-mat-wht-blk?variant=46818937831750" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/CLCBLACK_eee9a562-25b7-41f9-b3e3-38c0447db661_600x600.jpg?v=1691657649" itemprop="image"/>, <meta content='- Autry CLC Low M "Mat Wht/Blk"- Colour: White / Black / Cream- Stijlcode: ROLMMM04' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta 42"="" content="CLUB C REVENGE " itemprop="name" retgol"-=""/>, <meta content="https://www.sneakerbaas.com/products/club-c-revenge-ftwwht-vecnav-retgol?variant=46876997648710" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/1_3f1957f7-dd83-4b71-9297-ab207172c78b_600x600.png?v=1687440842" itemprop="image"/>, <meta content='- Reebok Classics CLUB C REVENGE "FTWWHT/VECNAV/RETGOL"- Colour: White/Creme/Orange/Blue- Stijlcode: 100033028' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="79.99" itemprop="price"/>]
# [<meta 41"="" cloud="" content="Sky Medal ß " gables"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/sky-medal-cloud-gables?variant=47077546230086" itemprop="url"/>, <meta content="Mizuno" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/mizunogables_d56a8f4f-7e49-402f-a94f-df0b2919e011_600x600.jpg?v=1691753868" itemprop="image"/>, <meta content='- Mizuno Sky Medal ß "Cloud / Gables"- Colour: Brown / Cream / Green- Stijlcode: D1GA238601' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="159.95" itemprop="price"/>]
# [<meta 37"="" content="Aussie " dove"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/aussie-athluxe-dove-white?variant=48505751798086" itemprop="url"/>, <meta content="KangaROOS" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_391_fb15edd1-653a-4fae-ad37-d0cac855f0c6_600x600.png?v=1694520463" itemprop="image"/>, <meta content='- KangaROOS AUSSIE ATHLUXE "dove/white"- Colour: Grey / White- Stijlcode:
# 603000-000-2602' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="129.95" itemprop="price"/>, <meta charset="utf-8"/>]
# [<meta 40"="" content="Air Max 95 " itemprop="name" red"-="" track=""/>, <meta content="https://www.sneakerbaas.com/products/air-max-95-track-red?variant=47090488803654" itemprop="url"/>, <meta content="Nike" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/ninetyfive_19220273-e492-4677-80f0-c151ee3bc659_600x600.jpg?v=1691658542" itemprop="image"/>, <meta content='- Nike Air Max 95 "Track Red"- Colour: Black / Grey / Red- Stijlcode: DM0011-007' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta 44"="" content="BB Court Lo " itemprop="name" white"-=""/>, <meta content="https://www.sneakerbaas.com/products/bb-court-lo-quiet-grey?variant=47090539561286" itemprop="url"/>, <meta content="Sergio Tacchini" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/sergiowit_a44c6f86-81e9-4ef6-9e3b-4875ad09b65c_600x600.jpg?v=1692178991" itemprop="image"/>, <meta content='- Sergio Tacchini BB Court Lo "Quiet Grey"- Colour: White / Grey- Stijlcode: TSTU0004L-3501' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" content="CLUB C Bulc " itemprop="name" vargre"-=""/>, <meta content="https://www.sneakerbaas.com/products/club-c-bulc-ftwwht-vargre-chalk?variant=46876998861126" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/100032937_600x600.png?v=1694616240" itemprop="image"/>, <meta content='- Reebok CLUB C Bulc "FTWWHT/VARGRE/CHALK"- Colour: White / Green- Stijlcode: 100032937' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="119.95" itemprop="price"/>]
# [<meta 41"="" clabur"-="" content="CLUB C Bulc " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/club-c-bulc-ftwwht-clabur-chalk?variant=46876996862278" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/100032938_600x600.png?v=1694615681" itemprop="image"/>, <meta content='- Reebok CLUB C BULC "FTWWHT/CLABUR/CHALK"- Colour: White / Red- Stijlcode: 100032938' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="119.95" itemprop="price"/>]
# [<meta 40.5"="" content="Slipstream Xtreme " itemprop="name" red"-=""/>, <meta content="https://www.sneakerbaas.com/products/slipstream-xtreme-color-regal-red?variant=48478562353478" itemprop="url"/>, <meta content="PUMA Sportstyle" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_312_5cb52438-109b-429c-a607-6ea3e8427ed5_600x600.png?v=1693484473" itemprop="image"/>, <meta content='- Puma Slipstream Xtreme Color "Regal Red"- Colour: White / Blue / Red- Stijlcode: 394695-2' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="139.95" itemprop="price"/>]
# [<meta 41"="" content="Sky Medal ß " itemprop="name" sand"-=""/>, <meta content="https://www.sneakerbaas.com/products/sky-medal-sand-coffee?variant=47077545640262" itemprop="url"/>, <meta content="Mizuno" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/mizunocoffee_6cb14e9a-4bf3-4a2b-8550-66b0796ea13b_600x600.jpg?v=1691753781" itemprop="image"/>, <meta content='- Mizuno Sky Medal ß "Sand / Coffee"- Colour: Beige / Brown / Cream- Stijlcode: D1GA238603' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="159.95" itemprop="price"/>]
# [<meta content="Rijksmuseum ''Melkmeisje''- 37" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/contender-x-rijksmuseum-melkmeisje?variant=47103369314630" itemprop="url"/>, <meta content="Mizuno" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/RM1_600x600.jpg?v=1692088501" itemprop="image"/>, <meta content='- Mizuno Contender x Rijksmuseum "Melkmeisje"- Colour: Grey / Blue / White- Stijlcode: D1GD232201' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="119.95" itemprop="price"/>]
# [<meta 43"="" content="CLC Low M " green"-="" itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/clc-low-m-mat-wht-gr-pk?variant=46818938913094" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/ROLMMM07_cd53d42d-1a6b-48c8-9967-e4892b9928e3_600x600.jpg?v=1690364751" itemprop="image"/>, <meta content='- Autry CLC Low M "Mat Wht/Gr/Pk"- Colour: White / Green / Pink- Stijlcode: ROLMMM07' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="189.95" itemprop="price"/>]
# [<meta 40"="" content="Air Trainer 1 " itemprop="name" split"-=""/>, <meta content="https://www.sneakerbaas.com/products/air-trainer-1-white-red?variant=46958481047878" itemprop="url"/>, <meta content="Nike" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Trainer1_600x600.jpg?v=1689063475" itemprop="image"/>, <meta content='- Nike Air Trainer "White / Red"- Colour: White / Cream / Red- Stijlcode: DZ2547-100' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="99.99" itemprop="price"/>]
# [<meta 41"="" clamar"-="" content="CLUB C REVENGE " itemprop="name"/>, <meta content="https://www.sneakerbaas.com/products/club-c-revenge-chalk-clamar-pugry3?variant=46876998238534" itemprop="url"/>, <meta content="Reebok Classics" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schoen1_1c1cc917-c625-4fcd-bb7b-04874b3679b7_600x600.png?v=1687441414" itemprop="image"/>, <meta content='- Reebok Classics CLUB C REVENGE "CHALK/CLAMAR/PUGRY3"- Colour: Creme/Beige/Red- Stijlcode: 100032877' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="79.99" itemprop="price"/>]
# [<meta 44"="" content="Medalist Low M " hair="" itemprop="name" space"-=""/>, <meta content="https://www.sneakerbaas.com/products/medalist-low-m-suede-hair-space?variant=46818939928902" itemprop="url"/>, <meta content="Autry" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/AULMSH03_b233e228-30b5-453b-a977-b42e471516ca_600x600.jpg?v=1690364000" itemprop="image"/>, <meta content='- Autry Medalist Low M "Suede/Hair Space"- Colour: Black / White / Cream- Stijlcode: AULMSH03' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="179.95" itemprop="price"/>]
# [<meta 44.5"="" content="Shadow 5000 " green"-="" itemprop="name" yellow=""/>, <meta content="https://www.sneakerbaas.com/products/shadow-5000-yellow-green?variant=47077549572422" itemprop="url"/>, <meta content="Saucony" itemprop="brand"/>, <meta content="//www.sneakerbaas.com/cdn/shop/files/Schermopname_207_92d579b4-80ad-460b-bd11-e0b26c9dcdda_600x600.png?v=1691480625" itemprop="image"/>, <meta content='- Saucony Shadow 5000 "Yellow / Green"- Colour: Cream / Green / Red- Stijlcode: S70784-4' itemprop="description"/>, <meta content="EUR" itemprop="priceCurrency"/>, <meta content="144.95" itemprop="price"/>]

# %%
import pandas as pd


df = pd.DataFrame(full_metadata)
df
# Out:
#                 brand priceCurrency   price  \
# 0     Reebok Classics           EUR  179.95
# 1             Saucony           EUR  154.95
# 2     Reebok Classics           EUR  159.95
# 3              Clarks           EUR  269.95
# 4               Autry           EUR  179.95
# 5               Autry           EUR  189.95
# 6             Saucony           EUR  109.95
# 7             Saucony           EUR  129.95
# 8     PUMA Sportstyle           EUR  139.95
# 9   Saucony Originals           EUR  144.95
# 10              Autry           EUR  189.95
# 11             Clarks           EUR  169.95
# 12    Sergio Tacchini           EUR  139.95
# 13  Saucony Originals           EUR  144.95
# 14              Autry           EUR  189.95
# 15             Clarks           EUR  159.95
# 16             Mizuno           EUR  149.95
# 17              Autry           EUR  184.95
# 18    PUMA Sportstyle           EUR  139.95
# 19             Clarks           EUR  169.95
# 20   adidas Originals           EUR  119.95
# 21             Clarks           EUR  159.95
# 22  Saucony Originals           EUR  144.95
# 23              Karhu           EUR   69.99
# 24    PUMA Sportstyle           EUR  139.95
# 25    Reebok Classics           EUR  119.95
# 26             Clarks           EUR  269.95
# 27              Autry           EUR  179.95
# 28              Autry           EUR  189.95
# 29    Reebok Classics           EUR   79.99
# 30             Mizuno           EUR  159.95
# 31          KangaROOS           EUR  129.95
# 32               Nike           EUR  189.95
# 33    Sergio Tacchini           EUR  139.95
# 34    Reebok Classics           EUR  119.95
# 35    Reebok Classics           EUR  119.95
# 36    PUMA Sportstyle           EUR  139.95
# 37             Mizuno           EUR  159.95
# 38             Mizuno           EUR  119.95
# 39              Autry           EUR  189.95
# 40               Nike           EUR   99.99
# 41    Reebok Classics           EUR   79.99
# 42              Autry           EUR  179.95
# 43            Saucony           EUR  144.95
#
#                                           Description  \
# 0            Reebok SHAQ ATTAQ "FTWWHT/CBLACK/GOLDMT"
# 1                Saucony Shadow 6000 "Purple / Black"
# 2               Reebok PUMP TZ "FTWWHT/CBLACK/SOACYE"
# 3                    Clarks Wallabee Eden "Dark Sand"
# 4             Autry Medalist Low M "Leat Wht/Malachi"
# 5                       Autry CLC Low M "Mat Wht/Pbl"
# 6             Saucony Grid Shadow 2 OG "Blue / White"
# 7                 Saucony Grid Shadow 2 "Creek Marsh"
# 8        Puma Slipstream Xtreme Color "Yellow Sizzle"
# 9                        Saucony Shadow 5000 "Forest"
# 10                    Autry CLC Low M "Mat Wht/Vi/Or"
# 11                        Clarks Weaver "Black Suede"
# 12          Sergio Tacchini BB Court Lo "Tibetan Red"
# 13                         Saucony Shadow 5000 "Rust"
# 14                       Autry CLC Low M "Mat Wht/Rd"
# 15                        Clarks Wallabee Mid "Green"
# 16                       Mizuno Contender(U) "Rgreen"
# 17             Autry Medalist Low M "Suede Bttl/Blue"
# 18           Puma Slipstream Xtreme Earth "Sand Dune"
# 19                               Clarks Weaver "Cola"
# 20  adidas Originals Handball Spezial "Black / White"
# 21                          Clarks Wallabee "Beeswax"
# 22                 Saucony Shadow 5000 "Grey / Green"
# 23                           Karhu Legacy OG "Purple"
# 24              Puma Slipstream Xtreme Earth "Cashew"
# 25          Reebok CLUB C Bulc "CBLACK/CBLACK/TEAYEL"
# 26                       Clarks Wallabee Eden "Black"
# 27              Autry Medalist Low M "Leat Wht/Syrah"
# 28                      Autry CLC Low M "Mat Wht/Blk"
# 29  Reebok Classics CLUB C REVENGE "FTWWHT/VECNAV/...
# 30                Mizuno Sky Medal ß "Cloud / Gables"
# 31              KangaROOS AUSSIE ATHLUXE "dove/white"
# 32                        Nike Air Max 95 "Track Red"
# 33           Sergio Tacchini BB Court Lo "Quiet Grey"
# 34           Reebok CLUB C Bulc "FTWWHT/VARGRE/CHALK"
# 35           Reebok CLUB C BULC "FTWWHT/CLABUR/CHALK"
# 36           Puma Slipstream Xtreme Color "Regal Red"
# 37                 Mizuno Sky Medal ß "Sand / Coffee"
# 38        Mizuno Contender x Rijksmuseum "Melkmeisje"
# 39                    Autry CLC Low M "Mat Wht/Gr/Pk"
# 40                     Nike Air Trainer "White / Red"
# 41  Reebok Classics CLUB C REVENGE "CHALK/CLAMAR/P...
# 42            Autry Medalist Low M "Suede/Hair Space"
# 43               Saucony Shadow 5000 "Yellow / Green"
#
#                              Colors                     Stijlcode  \
# 0      Colour: Black / White / Gold          Stijlcode: 100032830
# 1    Colour: Purple / Coral / Black           Stijlcode: S70784-1
# 2      Colour: White / Black / Neon          Stijlcode: 100033132
# 3                     Beige / Cream           Stijlcode: 26173319
# 4      Colour: Mint / White / Cream           Stijlcode: AULMWB30
# 5              Colour: White / Blue           Stijlcode: ROLMMM06
# 6      Colour: White / Blue / Black           Stijlcode: S70772-1
# 7      Colour: Green / Blue / White           Stijlcode: S70782-1
# 8    Colour: White / Green / Yellow           Stijlcode: 394695-1
# 9     Colour: Green / Cream / White           Stijlcode: S70778-1
# 10  Colour: Cream / Purple / Orange           Stijlcode: ROLMMM08
# 11                    Colour: Black           Stijlcode: 26165081
# 12      Colour: White / Red / Cream     Stijlcode: TSTU0004L-3502
# 13    Colour: Orange / Grey / White           Stijlcode: S70778-2
# 14              Colour: White / Red           Stijlcode: ROLMMM12
# 15                    Colour: Green           Stijlcode: 26173640
# 16   Colour: Green / White / Orange        Stijlcode: D1GA2369-03
# 17     Colour: Green / Blue / Cream           Stijlcode: AULMSS17
# 18             Colour: Grey / Beige           Stijlcode: 394696-1
# 19            Colour: Brown / Beige           Stijlcode: 26165082
# 20            Colour: Black / White             Stijlcode: DB3021
# 21            Colour: Brown / Cream           Stijlcode: 26156605
# 22      Colour: Grey / Green / Pink           Stijlcode: S70779-2
# 23             Colour: White/Purple            Stylecode: F806001
# 24    Colour: Beige / Green / Black           Stijlcode: 394696-2
# 25           Colour: Black / Yellow          Stijlcode: 100034265
# 26            Colour: Black / Cream           Stijlcode: 26173320
# 27              Colour: Red / White           Stijlcode: AULMWB35
# 28    Colour: White / Black / Cream           Stijlcode: ROLMMM04
# 29  Colour: White/Creme/Orange/Blue          Stijlcode: 100033028
# 30    Colour: Brown / Cream / Green         Stijlcode: D1GA238601
# 31             Colour: Grey / White  Stijlcode: \n603000-000-2602
# 32       Colour: Black / Grey / Red         Stijlcode: DM0011-007
# 33             Colour: White / Grey     Stijlcode: TSTU0004L-3501
# 34            Colour: White / Green          Stijlcode: 100032937
# 35              Colour: White / Red          Stijlcode: 100032938
# 36       Colour: White / Blue / Red           Stijlcode: 394695-2
# 37    Colour: Beige / Brown / Cream         Stijlcode: D1GA238603
# 38      Colour: Grey / Blue / White         Stijlcode: D1GD232201
# 39     Colour: White / Green / Pink           Stijlcode: ROLMMM07
# 40      Colour: White / Cream / Red         Stijlcode: DZ2547-100
# 41          Colour: Creme/Beige/Red          Stijlcode: 100032877
# 42    Colour: Black / White / Cream           Stijlcode: AULMSH03
# 43      Colour: Cream / Green / Red           Stijlcode: S70784-4
#
#                                title  \
# 0                  Shaq Attaq "Gold"
# 1       Shadow 6000 "Purple / Black"
# 2                     Pump TZ "Neon"
# 3          Wallabee Eden "Dark Sand"
# 4           Medalist Low M "Malachi"
# 5                   CLC Low M "Blue"
# 6                   Grid Shadow 2 OG
# 7                      Grid Shadow 2
# 8         Slipstream Xtreme "Yellow"
# 9               Shadow 5000 "Forest"
# 10                CLC Low M "Violet"
# 11              Weaver "Black Suede"
# 12         BB Court Lo "Tibetan Red"
# 13                Shadow 5000 "Rust"
# 14                   CLC Low M "Red"
# 15              Wallabee Mid "Green"
# 16                Contender "RGreen"
# 17       Medalist Low M "Suede Bttl"
# 18     Slipstream Xtreme "Sand Dune"
# 19                     Weaver "Cola"
# 20          Handball Spezial "Black"
# 21                Wallabee "Beeswax"
# 22        Shadow 5000 "Grey / Green"
# 23                Legacy OG "Purple"
# 24  Slipstream Xtreme Earth "Cashew"
# 25              Club C Bulc "Teayel"
# 26             Wallabee Eden "Black"
# 27              Medalist Low "Syrah"
# 28                 CLC Low M "Black"
# 29           CLUB C REVENGE "RETGOL"
# 30      Sky Medal ß "Cloud / Gables"
# 31                     Aussie "Dove"
# 32            Air Max 95 "Track Red"
# 33               BB Court Lo "White"
# 34              CLUB C Bulc "Vargre"
# 35              CLUB C Bulc "Clabur"
# 36           Slipstream Xtreme "Red"
# 37                Sky Medal ß "Sand"
# 38        Rijksmuseum ''Melkmeisje''
# 39                 CLC Low M "Green"
# 40             Air Trainer 1 "Split"
# 41           CLUB C REVENGE "CLAMAR"
# 42       Medalist Low M "Hair Space"
# 43      Shadow 5000 "Yellow / Green"
#
#                                           photos_path
# 0                parser/sneakerbaas/Shaq Attaq "Gold"
# 1     parser/sneakerbaas/Shadow 6000 "Purple / Black"
# 2                   parser/sneakerbaas/Pump TZ "Neon"
# 3        parser/sneakerbaas/Wallabee Eden "Dark Sand"
# 4         parser/sneakerbaas/Medalist Low M "Malachi"
# 5                 parser/sneakerbaas/CLC Low M "Blue"
# 6                 parser/sneakerbaas/Grid Shadow 2 OG
# 7                    parser/sneakerbaas/Grid Shadow 2
# 8       parser/sneakerbaas/Slipstream Xtreme "Yellow"
# 9             parser/sneakerbaas/Shadow 5000 "Forest"
# 10              parser/sneakerbaas/CLC Low M "Violet"
# 11            parser/sneakerbaas/Weaver "Black Suede"
# 12       parser/sneakerbaas/BB Court Lo "Tibetan Red"
# 13              parser/sneakerbaas/Shadow 5000 "Rust"
# 14                 parser/sneakerbaas/CLC Low M "Red"
# 15            parser/sneakerbaas/Wallabee Mid "Green"
# 16              parser/sneakerbaas/Contender "RGreen"
# 17     parser/sneakerbaas/Medalist Low M "Suede Bttl"
# 18   parser/sneakerbaas/Slipstream Xtreme "Sand Dune"
# 19                   parser/sneakerbaas/Weaver "Cola"
# 20        parser/sneakerbaas/Handball Spezial "Black"
# 21              parser/sneakerbaas/Wallabee "Beeswax"
# 22      parser/sneakerbaas/Shadow 5000 "Grey / Green"
# 23              parser/sneakerbaas/Legacy OG "Purple"
# 24  parser/sneakerbaas/Slipstream Xtreme Earth "Ca...
# 25            parser/sneakerbaas/Club C Bulc "Teayel"
# 26           parser/sneakerbaas/Wallabee Eden "Black"
# 27            parser/sneakerbaas/Medalist Low "Syrah"
# 28               parser/sneakerbaas/CLC Low M "Black"
# 29         parser/sneakerbaas/CLUB C REVENGE "RETGOL"
# 30    parser/sneakerbaas/Sky Medal ß "Cloud / Gables"
# 31                   parser/sneakerbaas/Aussie "Dove"
# 32          parser/sneakerbaas/Air Max 95 "Track Red"
# 33             parser/sneakerbaas/BB Court Lo "White"
# 34            parser/sneakerbaas/CLUB C Bulc "Vargre"
# 35            parser/sneakerbaas/CLUB C Bulc "Clabur"
# 36         parser/sneakerbaas/Slipstream Xtreme "Red"
# 37              parser/sneakerbaas/Sky Medal ß "Sand"
# 38      parser/sneakerbaas/Rijksmuseum ''Melkmeisje''
# 39               parser/sneakerbaas/CLC Low M "Green"
# 40           parser/sneakerbaas/Air Trainer 1 "Split"
# 41         parser/sneakerbaas/CLUB C REVENGE "CLAMAR"
# 42     parser/sneakerbaas/Medalist Low M "Hair Space"
# 43    parser/sneakerbaas/Shadow 5000 "Yellow / Green"

# %%
df.to_csv("parser/sneakerbaas/metadata.csv", index=False)
