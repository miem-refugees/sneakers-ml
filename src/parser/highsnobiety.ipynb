# %% [markdown]
# ## Algolia - CRM-система со встроенным ранжированием поисков пользователей.
#
# Используется в:
# - https://www.highsnobiety.com/en-us/shop/category/footwear/sneakers/
# - https://www.kickscrew.com/collections/

# %%
# !pip install algoliasearch

# %%
import json
import os
import urllib.parse
import requests
import pandas as pd
from fake_useragent import UserAgent


from algoliasearch.search_client import SearchClient

HEADERS = {"User-Agent": UserAgent().random}

# %%
client = SearchClient.create('KV0RT3PJZC', '37e783b9d54217566682938fa0e2b0f6')
index = client.init_index('production_ec_products_improved_newest_first')

WEBSITE_NAME = 'highsnobiety'

# %% [markdown]
# Search api reference: https://www.algolia.com/doc/api-reference/api-methods/search
#
# Доступные категории:
#
# - category/footwear/sneakers - все кроссовки
# - brand/adidas/sneakers - по бренду

# %%
resp = index.search('', {
    'filters': 'localizedPages.en:category/footwear/sneakers AND outOfStockForLongTime:false',
    'page': 1
})

print(len(resp['hits']))
json.dumps(resp)
# Out:
# 20
# '{"hits": [{"filterBrand": [{"key": "salomon", "label": "Salomon"}, {"key": "and_wander", "label": "And Wander"}], "displayBrand": "Salomon x And Wander", "displayName": {"en": "Salomon x And Wander \\u2013 XA Pro 3D GORE-TEX Brown"}, "collaboration": null, "allCategories": [{"id": "e1981069-a727-454c-a6f9-fc31d6b18d6b", "name": {"en": "Sneakers"}}, {"id": "1e344ca3-2b83-411c-8037-5cd03e5de6b4", "name": {"en": "Footwear"}}], "categories": [{"id": "e1981069-a727-454c-a6f9-fc31d6b18d6b", "name": {"en": "Sneakers"}}], "outOfStockForLongTime": false, "campaignId": "HS_IO_EU_2023_4347", "colors": {"en": ["Brown"]}, "image": "https://www.highsnobiety.com/static-assets/thumbor/8bj_L6VZDJz9EjPtdo6RfR7dnQY=/fit-in/790x987/https://aaba6fc7dd05e6321705-d3c8e77fedf34b64ceac1fa28b6c145b.ssl.cf3.rackcdn.com/SALOMON%20x%20And%20Wander-GiujSbPT.jpg", "isAvailable": true, "isDiscounted": false, "key": "281568", "name": {"en": "XA Pro 3D GORE-TEX Brown"}, "productType": {"id": "9407b898-e03f-4bd6-9ff1-814236bb092a", "name": "Shoes"}, "published": true, "responsiveImages": [{"url": "https://www.highsnobiety.com/static-assets/thumbor/cWzCTVKTFb3JxVn2AzCE0uDujKs=/fit-in/37x46/https://aaba6fc7dd05e6321705-d3c8e77fedf34b64ceac1fa28b6c145b.ssl.cf3.rackcdn.com/SALOMON%20x%20And%20Wander-GiujSbPT.jpg", "dimensions": {"width": 37, "height": 46}}, {"url": "https://www.highsnobiety.com/static-assets/thumbor/QyqNCyZK84iY8z2Votlmy4F0y5M=/fit-in/375x468/https://aaba6fc7dd05e6321705-d3c8e77fedf34b64ceac1fa28b6c145b.ssl.cf3.rackcdn.com/SALOMON%20x%20And%20Wander-GiujSbPT.jpg", "dimensions": {"width": 375, "height": 468}}, {"url": "https://www.highsnobiety.com/static-assets/thumbor/8bj_L6VZDJz9EjPtdo6RfR7dnQY=/fit-in/790x987/https://aaba6fc7dd05e6321705-d3c8e77fedf34b64ceac1fa28b6c145b.ssl.cf3.rackcdn.com/SALOMON%20x%20And%20Wander-GiujSbPT.jpg", "dimensions": {"width": 790, "height": 987}}], "sizes": {"USD": ["45 1/3", "46 2/3"], "EUR": ["45 1/3", "46 2/3"], "CAD": ["45 1/3", "46 2/3"], "CHF": ["45 1/3", "46 2/3"], "CNY": ["45 1/3", "46 2/3"], "DKK": ["45 1/3", "46 2/3"], "GBP": ["45 1/3", "46 2/3"], "HKD": ["45 1/3", "46 2/3"], "JPY": ["45 1/3", "46 2/3"], "NOK": ["45 1/3", "46 2/3"], "SEK": ["45 1/3", "46 2/3"], "SGD": ["45 1/3", "46 2/3"]}, "sku": "TSALAWSNKR014113", "slug": {"en": "salomon-and-wander-xa-pro-3d-gore-tex-brown"}, "upcoming": false, "upcomingEndDate": 0, "earlyAccessAppEndDate": 0, "price": {"AE": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "AL": {"centAmount": 29000, "currencyCode": "EUR", "originalPriceCentAmount": 29000, "isDiscounted": false}, "AT": {"centAmount": 29000, "currencyCode": "EUR", "originalPriceCentAmount": 29000, "isDiscounted": false}, "AU": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "AW": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "BB": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "BE": {"centAmount": 29000, "currencyCode": "EUR", "originalPriceCentAmount": 29000, "isDiscounted": false}, "BG": {"centAmount": 29000, "currencyCode": "EUR", "originalPriceCentAmount": 29000, "isDiscounted": false}, "BH": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "BL": {"centAmount": 29000, "currencyCode": "EUR", "originalPriceCentAmount": 29000, "isDiscounted": false}, "BM": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "BR": {"centAmount": 37000, "currencyCode": "USD", "originalPriceCentAmount": 37000, "isDiscounted": false}, "CA": {"centAmount": 43500, "currencyCode": "CAD", "originalPriceCentAmount": 43500, "isDiscounted": false}, "CH": {"centAmount": 39500, "currencyCode": "CHF", "originalPriceCentAmount": 39500, "isDiscounted": false}, "CN": {"centAmount": 265000, "currencyCode": "CNY", "or ...

# %%
print(f"""INFO
"nbHits: {resp["nbHits"]}
"nbPages": {resp["nbPages"]},
"hitsPerPage": {resp["hitsPerPage"]}""")
# Out:
# INFO
# "nbHits: 690
# "nbPages": 35,
# "hitsPerPage": 20

# %%
def get_image_extension(url):
    return '.' + url[-5:].split('.')[-1]

def get_metadata(item):
    slug = item["slug"]["en"]
    us_price = item['price'].get('US', {})
    price = int(us_price.get('centAmount', 0)) / 100
    brand = item['displayBrand']
    image_url = item['image']

    photo_folder = os.path.join(
        WEBSITE_NAME,
        "photos",
        brand
    )
    image_path = os.path.join(
        photo_folder,
        slug + get_image_extension(image_url), # TODO: more photos needed
    )

    metadata = {
        'url': f'https://www.highsnobiety.com/en-us/shop/product/{slug}',
        'brand': brand,
        # 'description': item.get('displayName', {}).get('en'),
        'priceCurrency': us_price['currencyCode'],
        'price': price,
        'title': item.get('displayName', {}).get('en').replace('\\u', ''),
        'photo_path': image_path,
    }

    img_binary = requests.get(image_url).content
    os.makedirs(photo_folder, exist_ok=True)
    with open(image_path,"wb",) as f:
        f.write(img_binary)

    return metadata

# %%
#
# MAIN
# 

# full_metadata = []
# full_metadata_items = set()

for page in range(1, 20):
    resp = index.search('', {
        'filters': 'localizedPages.en:category/footwear/sneakers AND outOfStockForLongTime:false',
        'page': page,
        'hitsPerPage': 100
    })
    print(f'processing page {page} with {len(resp["hits"])} items')
    for hit in resp['hits']:
        print('Processing brand:', hit["displayBrand"])
        metadata = get_metadata(hit)
        if metadata['url'] in full_metadata_items:
            print(metadata['title'], 'is already parsed')
            continue
        
        full_metadata.append(metadata)
        full_metadata_items.add(metadata['title'])

df = pd.DataFrame(full_metadata)
df.to_csv(f"{WEBSITE_NAME}/metadata.csv", index=False)

# %%
# test
assert '.jpeg' == get_image_extension('https://www.highsnobiety.com/static-assets/thumbor/IU5Ni6j11Tuupckbzwx8EnkKeZw=/fit-in/790x987/https://aaba6fc7dd05e6321705-d3c8e77fedf34b64ceac1fa28b6c145b.ssl.cf3.rackcdn.com/asics-gel-venture-6--qin0ZV1i.jpeg')
'ok'
# Out:
# 'ok'

# %%
df.shape
# Out:
# (380, 6)
