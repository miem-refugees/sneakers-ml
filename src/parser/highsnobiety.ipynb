# %% [markdown]
# ## Algolia - CRM-система со встроенным ранжированием поисков пользователей.
#
# Используется в:
# - https://www.highsnobiety.com/en-us/shop/category/footwear/sneakers/
# - https://www.kickscrew.com/collections/
#
# Search api reference: https://www.algolia.com/doc/api-reference/api-methods/search
#
# ### highsnobiety
# Доступные категории:
#
# - category/footwear/sneakers - все кроссовки
# - brand/adidas/sneakers - по бренду
#
# ### kickscrew
# Доступные категории:
#
# - TODO
# - TODO

# %%
# !pip install algoliasearch pandas beautifulsoup

import os
import requests
import pandas as pd

from algoliasearch.search_client import SearchClient
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
from typing import Callable

# %%
from tqdm import tqdm


class ParsePipeline:

    def __init__(self, website_name, parser: Callable):
        self.WEBSITE_NAME = website_name
        self.parser = parser
        self.unique_items = set()

    @staticmethod
    def get_image_extension(url: str) -> str:
        return '.' + url[-5:].split('.')[-1]

    def save_to_filesystem(self, brand: str, slug: str, image_url: str) -> str:
        photo_folder = os.path.join(self.WEBSITE_NAME, "photos", brand)
        os.makedirs(photo_folder, exist_ok=True)

        image_path = os.path.join(
            photo_folder,
            slug + self.get_image_extension(image_url),  # TODO: more photos needed
        )

        img_binary = requests.get(image_url).content
        os.makedirs(photo_folder, exist_ok=True)
        with open(image_path, "wb") as f:
            f.write(img_binary)
        return image_path

    def process_item(self, item: dict) -> dict:
        return self.parser(item)

    def parse(self, filters: str, pages: int = 10, hit_per_page: int = 100) -> list:
        full_metadata = []
        for page in tqdm(range(1, pages)):
            resp = index.search('', {
                'filters': filters,
                'page': page,
                'hitsPerPage': hit_per_page
            })
            print(f'processing page {page} with {len(resp["hits"])} items')
            for hit in resp['hits']:
                print(f'Processing brand: {hit["displayBrand"]}')
                metadata = self.process_item(hit)
                if metadata['url'] in self.unique_items:
                    print(metadata['title'], 'is already parsed')
                    continue

                full_metadata.append(metadata)
                self.unique_items.add(metadata['title'])
        print(f"finished parse with {len(full_metadata)} items")
        return full_metadata

    async def parse_more_images(self, metadata: dict):
        if metadata.get('right-side-img') is not None:
            print(f"skipped {metadata['slug']}")
            return

        print(f"processing {metadata['slug']}")
        r = requests.get(metadata['url'], headers={"User-Agent": UserAgent().random})
        try:
            r.raise_for_status()
        except Exception as e:
            print(f"could not request page {metadata['url']} - {e}")
            return

        soup = BeautifulSoup(r.text, "html.parser")
        metadata['description'] = soup.select('#acc-controls-details-editorsnote > div > p')[0].text

        image_side = {
            'right-side-img': '#pdp_image_zoom_0',
            'left-side-img': '#pdp_image_zoom_1',
            'front-both-img': '#pdp_image_zoom_2'
        }
        for side, tag in image_side.items():
            t = soup.select(tag)
            if len(t) > 0:
                img_link = t[0]['srcset'].split(', ')[0].split()[0]
                img_path = self.save_to_filesystem(metadata['brand'], f"{metadata['slug']}-{side}", img_link)
                metadata[side] = img_path
        print(f"{metadata['slug']} is done")

# %%
#
# highsnobiety
# 
client = SearchClient.create('KV0RT3PJZC', '37e783b9d54217566682938fa0e2b0f6')
index = client.init_index('production_ec_products_improved_newest_first')
WEBSITE_NAME = 'highsnobiety'


def highsnobiety_parser(item: dict) -> dict:
    us_price = item['price'].get('US', {})
    return {
        'url': f'https://www.highsnobiety.com/en-us/shop/product/{item["slug"]["en"]}',
        'brand': item['displayBrand'],
        'slug': item["slug"]["en"],
        'priceCurrency': us_price['currencyCode'],
        'price': int(us_price.get('centAmount', 0)) / 100,
        'title': item.get('displayName', {}).get('en').replace('\\u', '')
    }


parser = ParsePipeline(WEBSITE_NAME, highsnobiety_parser)
parse_result = parser.parse(
    'localizedPages.en:category/footwear/sneakers AND outOfStockForLongTime:false',
    20,
    100
)

# %%
import asyncio

ioloop = asyncio.get_event_loop()
coroutines = [ioloop.create_task(parser.parse_more_images(metadata)) for metadata in parse_result]
ioloop.run_until_complete(asyncio.wait(coroutines))
# Out:
# created for salomon-xt-quest-2-falcon-cement-bright-green
# created for salomon-acs-pro-pewter-monument-aegean-blue
# created for adidas-gazelle-core-black-gum
# created for converse-one-star-pro-ltd-ox-berlin-pink
# created for saucony-progrid-triumph-4-green-silver
# created for saucony-progrid-triumph-4-pink-silver
# created for saucony-progrid-triumph-4-blue-silver
# created for saucony-peregrine-13-st-glade-bronze
# created for asics-gel-kayano-14-pure-silver-pure-silver
# created for adidas-cg-split-stan-smith-beige-tonecore-black
# created for adidas-cg-split-stan-smith-core-blackgranite
# created for adidas-cg-split-stan-smith-whiteblack
# created for on-cloudultra-2-black
# created for on-cloudstratus-3-undyed-white-sand
# created for converse-pl-vulc-pro-ox-forest-shelter-white
# created for new-balance-bbw550sb-sea-salt-mercury-blue
# created for new-balance-mt580ed2-black-grey-white
# created for new-balance-bbw550sg-sea-salt-nori
# created for roa-katharina-sneakers-olive-rust
# created for roa-lhakpa-sneakers-green
# created for roa-andreas-boots-black
# created for roa-leather-loafer-brown
# created for puma-star-tennis-whites-whiteultra-bluegreen
# created for keen-jasper-cathay-spice-orion-blue
# created for keen-jasper-ii-wp-canteen-naval-academy
# created for keen-hiking-patrol-jasper-rocks-sp-phantasmal-red
# created for asics-gmbh-gel-kayano-legacy-cilantro-wood-crepe
# created for asics-gel-1130-oyster-gray-clay-gray
# created for asics-gel-1130-steel-gray-sheet-rock
# created for asics-gel-kayano-14-simply-taupe-oatmeal
# created for reebok-ltd-club-c-ltd-white-luxe-leather
# created for bape-highsnobiety-road-sta-express-beige-charcoal
# created for bape-highsnobiety-bape-sta-ivory
# created for puma-clyde-rhuigi-pristine-pristine-inky-blue
# created for puma-clyde-rhuigi-pristine-sedate-gray-white
# created for vans-og-style-93-lx-marshmallow
# created for asics-gel-venture-6-dark-sepia-dark-sepia
# created for veja-v-10-b-mesh-white-nautico
# created for veja-v-10-chrome-free-leather-white-black-sahara
# created for norda-001-yellow
# created for reebok-club-c-grounds-green
# created for puma-velophasis-technisch-white
# created for puma-velophasis-prm-beige
# created for puma-nanamica-clyde-gore-tex-white
# created for puma-velophasis-prm-black
# created for puma-velophasis-technisch-black
# created for puma-nanamica-clyde-gore-tex-black
# created for puma-velophasis-technisch-grey
# created for vans-ua-og-half-cab-lx-hairy-suede-grey-ridge
# created for roa-slip-on-sneaker-black
# created for new-balance-ml610tbj-deep-olive-green
# created for new-balance-ualgsbb-rainier-brown
# created for new-balance-u-9060-hsc-sea-salt
# created for new-balance-bb650rch-white
# created for new-balance-ml610tbi-dark-mushroom
# created for new-balance-u-9060-hsp-pink
# created for adidas-adimatic-black-2
# created for adidas-response-cl-white-black
# created for adidas-samba-og-navy-white
# created for adidas-state-brown
# created for adidas-orketro-white
# created for veja-v-90-pierre-white
# created for hoka-clifton-9-wide-black-black
# created for ranra-salomon-cross-pro-better-turmericblazing-orangescarlet-ibis
# created for ranra-salomon-cross-pro-better-cathay-spicekelpbright-lime-green
# created for salomon-acs-pro-vanilla-ice-lunar-rock-tomato-cream
# created for salomon-xt-4-og-white-ebony-lunar-rock
# created for salomon-xt-4-og-black-ebony-silver-metallic-x
# created for asics-gel-venture-6-ns-forest-black
# created for asics-gt-2160-dark-taupe-taupe-gray
# created for asics-gt-2160-white-shamrock-green
# created for asics-gel-quantum-kinetic-dark-sepia-shamrock-green
# created for asics-gel-venture-6-ns-white-pure-silver
# created for asics-gel-nyc-cream-oatmeal
# created for asics-gt-2160-oatmeal-simply-taupe
# created for new-balance-fresh-foam-hierro-v7-hot-marigold
# created for mizuno-wave-rider-10-white-cabernet-silver
# created for veja-v-10-white-black
# created for saucony-progrid-omni-9-silver-red
# created for keen-hiking-patrol-jasper-rocks-sp-cuban-beige
# created for new-balance-fresh-foam-trail-more-v3-black
# created for new-balance-fresh-foam-trail-more-v3-mindful-grey
# created for new-balance-wrpd-runner-sea-salt
# created for puma-star-strawberries-cream
# created for maison-margiela-leather-replica-sneakers-black-2
# created for puma-super-team-og-white
# created for new-balance-m1906de-white
# created for new-balance-m1906df-black
# created for new-balance-bb-650-rwi-white
# created for new-balance-ct-302-sg-white
# created for new-balance-u-997r-cb-grey
# created for new-balance-ct-302-sl-white
# created for new-balance-u-997r-cb-varsity-gold
# created for new-balance-bb-650-rwh-white
# created for new-balance-m-2002-rsh-magnet
# created for new-balance-ualgsvt-rainier-dune
# created for new-balance-m-2002-rsi-driftwood
# created for new-balance-u-9060-ecc-castlerock
# created for new-balance-wthigq7-raincloud
# created for veja-v-10-extra-white
# created for veja-campo-green
# created for veja-venturi-multi
# created for veja-v-12-white-camel
# created for veja-recife-logo-white
# created for hoka-project-clifton-blanc-de-blanc
# created for hoka-m-anacapa-low-gtx-black
# created for new-balance-mr530smd-bone
# created for new-balance-650-white
# created for adidas-stan-smith-80s
# created for keen-jasper-silver-mink
# created for veja-campo-white-natural
# created for on-po-cloudventure-peak-3-m
# created for on-pad-cloudmonster-1-m
# created for on-pr-cloudmonster-1-m
# created for on-pad-cloudnova-form-1-m-white-eclipse
# created for salomon-xt-6-aloe-wash-hazelnut-feather-gray
# created for merrell-reese-cooper-mtl-mqm-hunter-green
# created for merrell-reese-cooper-mtl-long-sky-2-otter-brown
# created for merrell-reese-cooper-mtl-long-sky-2-clover
# created for merrell-reese-cooper-hydro-runner-forest-night
# created for merrell-reese-cooper-mtl-mqm-pirate-black
# created for merrell-reese-cooper-hydro-runner-pebble
# created for new-balance-bb550tsf-white
# created for saucony-colour-companie-plus-grid-shadow-2-beach-ramble
# created for on-cloud-3-hunter-black
# created for on-the-roger-spin-undyed-white-yellow
# created for on-cloudwander-waterproof-pearl-root
# created for on-cloudvista-waterproof-zinc-grape
# created for reebok-club-c-black-light-pink
# created for reebok-club-c-beige-pale-blue
# created for puma-velophasis-phased-white-blue
# created for new-balance-fresh-foam-x-hierro-v7-gtx-cayenne
# created for salomon-xt-6-dried-herb-deep-lichen-green-bright-green
# created for new-balance-ct302of-white
# created for converse-turbowpn-mid-pelican-black-cloud-cream
# created for converse-drkshdw-dbl-drkstar-natural-ivory-black-egret
# created for converse-chuck-70-marquis-hi-tawny-owl-epic-dune
# created for converse-drkshdw-dbl-drkstar-hi-black-egret-white
# created for converse-ct70-canvas-ltd-hi-black-trek-evo
# created for converse-one-star-pro-ox-nomad-khaki-egret-black
# created for converse-as-1-pro-ox-white-fir-white
# created for mizuno-wave-rider-10-silver-tradewind-white
# created for camperlab-tossu-purple
# created for roa-katharina-sneaker-beige
# created for roa-neal-brown
# created for roa-neal-black
# created for roa-katharina-sneaker-black
# created for roa-suede-sandal-hybrid-dove
# created for adidas-bad-bunny-response-black
# created for veja-v-10-ripstop-nautico-pierre
# created for puma-velophasis-technisch-sedate-grey-cashew
# created for puma-velophasis-phased-black-white
# created for saucony-progrid-omni-9-silver-blue
# created for adidas-samba-decon-black
# created for mizuno-sky-medal-beta-green
# created for mizuno-wave-prophecy-12-white-silver
# created for mizuno-wave-rider-10-opal-grey
# created for moncler-trailgrip-lite-2-sneakers-blue-olive-green
# created for moncler-trailgrip-lite-2-low-top-sneakers
# created for moncler-trailgrip-gtx-low-top-sneakers-green-pink
# created for moncler-trailgrip-lite-2-sneakers-brown-green
# created for moncler-trailgrip-gtx-low-top-sneakers-white-2
# created for moncler-trailgrip-gtx-low-top-sneakers-khaki-grey
# created for moncler-trailgrip-gtx-low-top-sneakers-black-2
# created for adidas-gazelle-core-burgundy-green
# created for adidas-samba-decon-white-black-greone
# created for adidas-campus-black
# created for adidas-samba-og-white-green
# created for adidas-gazelle-core-blue-burgundy-green
# created for adidas-exomniac-black
# created for new-balance-bb-550-pwg-white
# created for new-balance-bb-550-pwd-turtledove
# created for new-balance-u9060bur-rich-oak
# created for new-balance-w991ggw-green
# created for new-balance-m991psg-grey-teal
# created for new-balance-u998gr-grey
# created for new-balance-ou576agg-grey
# created for new-balance-w-990-gl-6-cool-grey
# created for moncler-salehe-bembury-trailgrip-grain-sneakers-orange
# created for moncler-salehe-bembury-trailgrip-grain-sneakers-pink
# created for moncler-salehe-bembury-trailgrip-grain-sneakers-beige
# created for trussardi-retro-mule-sneaker-black
# created for trussardi-retro-runner-sneaker-black
# created for trussardi-retro-mule-sneaker-white
# created for new-balance-m990v6-cool-gray
# created for new-balance-bb550stg-white
# created for new-balance-bb550sta-white
# created for sean-wotherspoon-adidas-orketro-off-white
# created for asics-gel-venture-6-glacier-gray-pure-silver
# created for asics-gel-1130-white-clay-canyon
# created for asics-gel-kayano-14-white-pure-gold
# created for mizuno-wave-prophecy-beta-black
# created for puma-plexus-glacier-grey
# created for veja-v-12-leather-white-steel
# created for reebok-rbk-premier-road-plus-vi-black
# created for reebok-club-c-grounds-red
# created for reebok-bb-4000-ii-white
# created for reebok-pleasures-nano-6000-sandtrap-pebble-tin-grey
# created for reebok-club-c-85-vintage-taupe
# created for reebok-zig-kinetica-3-pure-grey-chalk
# created for reebok-club-c-85-vintage-chalk-brown
# created for puma-pleasures-velophasis-overdyed-grape-wine-mauve-pop
# created for vans-ua-authentic-vr3-sf-slws-fr
# created for vans-ua-old-skool-36-dx-psde-bla
# created for reebok-club-c-85-vintage-white
# created for athletics-footwear-zero-v1-black
# created for athletics-footwear-zero-v1-silver
# created for athletics-footwear-zero-v1-white
# created for camperlab-tormenta-brown
# created for camperlab-tormenta-beige
# created for maison-margiela-alex-hiking-boot-black-black
# created for acne-studios-barai-white
# created for y-3-terrex-swift-r3-gore-tex-black
# created for vans-ua-og-classic-slip-on-lx-year-of-the-rabbit-green
# created for vans-ua-og-authentic-lx-vault-checkerboard-beige
# created for vans-half-cab-cp-vr3-lx-hemp-dgr
# created for vans-ua-og-authentic-lx-vault-checkerboard-green
# created for vans-half-cab-cp-vr3-lx-hemp-whi
# created for merrell-moab-mesa-luxe-1trl-beige
# created for merrell-moab-hybrid-zip-gore-tex-1trl-green
# created for merrell-hydro-runner-rfl-1trl-beige
# created for merrell-moab-hybrid-zip-gore-tex-1trl-white
# created for merrell-moab-mesa-luxe-1trl-grey
# created for merrell-hydro-runner-rfl-1trl-black
# created for puma-clyde-base-white
# created for converse-chuck-70-plus-canvas-black-egret-black
# created for converse-chuck-70-plus-canvas-egret-black-egret
# created for converse-chuck-taylor-all-star-lugged-2-0-cyber-grey
# created for converse-chuck-70-hi-sunflower-black-egret
# created for converse-chuck-taylor-all-star-cx-desert-sunset-pale-putty-papyrus
# created for converse-chuck-70-hi-white-blue-imperial-blue
# created for converse-run-star-motion-cx-platform-egret-oat-milk-oat-milk
# created for converse-chuck-70-hi-desert-sand-egret-light-gold
# created for converse-chuck-70-ox-imperial-blue-white-black
# created for stepney-workers-club-dellow-s-strike-canvas-ecru
# created for adidas-wales-bonner-sl72-knit-dark-brown
# created for adidas-wales-bonner-sl72-knit-team-green
# created for stone-island-grime-turquoise-78fws033
# created for raf-simons-ultrasceptre-sneaker-blue
# created for raf-simons-ultrasceptre-sneaker-dark-blue
# created for raf-simons-ultrasceptre-sneaker-green
# created for adidas-stan-smith-crepe-grey
# created for adidas-nmd-s1
# created for merrell-moab-speed-zip-gore-tex-1trl-black
# created for maison-margiela-50-50-sneakers-white
# created for reebok-milk-makeup-classic-vegan-miy-vintage-chalk-vector-red-core-black
# created for reebok-milk-makeup-bb-4000-ii-vegan-vintage-chalk-vector-red-core-black
# created for saucony-highsnobiety-pro-grid-triumph-4-cream-white
# created for saucony-highsnobiety-pro-grid-triumph-4-silver-multi
# created for puma-clyde-soho-london-frosted-ivory-new-navy
# created for puma-clyde-soho-nyc
# created for new-balance-ualgsgp-dark-moss
# created for new-balance-urc30oa-vintage-indigo
# created for new-balance-ml-610-tah-dark-camo
# created for new-balance-ou-576-ann-navy
# created for new-balance-mt-580-hsc-grey
# created for new-balance-m-991-bgg-blue-grey
# created for new-balance-ualgsbg-true-brown
# created for new-balance-ml-610-tae-silver-metallic
# created for new-balance-bb650rgg-light-aluminum
# created for new-balance-bb480lng-white
# created for new-balance-ml-610-taf-black
# created for new-balance-mt-580-mdb-black
# created for new-balance-ml-610-tag-angora
# created for new-balance-bb650rcl-white
# created for new-balance-u-9060-mus-mushroom
# created for on-cloudventure-olive-fir
# created for on-cloudsurfer-white-frost
# created for on-cloudwander-waterproof-high-alpine-ivory-black
# created for on-cloudwander-waterproof-glacier-eclipse
# created for on-cloudultra-exclusive-flame-storm
# created for on-cloudvista-waterproof-metal-denim
# created for salomon-pulsar-advanced-vanila-feather-grey
# created for salomon-pulsar-advanced-black-black-pewter
# created for converse-drkshdw-turbodrk-chuck-70-laceless-hi-pink
# created for converse-drkshdw-turbodrk-chuck-70-laceless-hi-brown
# created for converse-trek-chuck-70-beige
# created for new-balance-bb650rce-white
# created for adidas-andre-saraiva-stan-smith-white-green
# created for adidas-orketro-aluminum-white
# created for salomon-acs-pro-peat-beluga-vintage-khaki
# created for salomon-xt-4-og-vanilla-ice-fiery-red-wht
# created for converse-run-star-motion-cx-platform-beach-stone
# created for new-balance-m2002rdl-driftwood
# created for converse-fragment-weapon-mid-white-sport-royal-black
# created for converse-herringbone-one-star-pro-ox-moms-potato-salad-egret-oat-milk
# created for converse-herringbone-chuck-70-hi-grassy-alligator-friend-oat-milk
# created for converse-herringbone-chuck-70-ox-engine-smoke-toad-beach-stone
# created for hoka-clifton-l-suede-beige
# created for hoka-m-bondi-8-white
# created for reebok-milk-makeup-club-c-85-vegan-vintage-chalk-vector-red-core-black
# created for saucony-3d-grid-hurricane-green-cream
# created for saucony-progrid-triumph-4-yellow-silver
# created for saucony-progrid-triumph-4-black-silver
# created for saucony-3d-grid-hurricane-grey-cream
# created for saucony-3d-grid-hurricane-brown-rust
# created for mizuno-wave-rider-10-white
# created for adidas-orketro-white-silver
# created for veja-v-15-chrome-free-leather-white-pierre-sahara
# created for veja-campo-chrome-free-leather-white-matcha
# created for new-balance-urainac-marblehead
# created for salomon-xt-slate-advanced-vanilla-rainy-day
# created for stone-island-grime-pistachio-78fws033
# created for mizuno-maharishi-wave-rider-10-olive-green
# created for new-balance-mr530bb-white
# created for new-balance-mr530ba-white
# created for saucony-grid-azura-2000-black-silver
# created for saucony-jazz-81-sand
# created for saucony-progrid-triumph-4-lemon
# created for saucony-progrid-triumph-4-white
# created for saucony-shadow-6000-suede-grey
# created for hoka-mafate-speed-2-flame-evening-primrose
# created for salomon-speedverse-prg-wht-vanila-phantm
# created for converse-chuck-70-ox-naturally-digital-burnt-honey-cyber-grey
# created for keen-uneek-dark-olive-sugar-brown
# created for converse-chuck-70-ox-squirrel-friend-egret-black
# created for converse-chuck-70-ox-summit-sage-egret-black
# created for salomon-and-wander-xt-slate-white
# created for salomon-and-wander-jungle-ultra-low-grey
# created for camperlab-tossu-beige
# created for camperlab-tossu-black
# created for camperlab-tossu-pink
# created for camperlab-tossu-green
# created for converse-chuck-70-hi-south-of-houston-white-sunlight-pale-putty
# created for converse-one-star-pro-ox-south-of-houston-pale-putty-natural-ivory
# created for adidas-terrex-and-wander-free-hiker-2-bronze-strata-matte-silver-grey-four
# created for salomon-pas-normal-studios-xa-alpine-2-moss-gray-deep-lichen-green-gull
# created for new-balance-m2002rxf-nb-navy
# created for vans-ua-authentic-vr3-pw-lx-beige
# created for puma-plexus-juun-j
# created for puma-clyde-base-black
# created for salomon-xt-6-rubber-lizard-eden
# created for converse-cons-alltimers-one-star-pro-ox-midnight-navy-navy
# created for new-balance-m1906rcd-silver-metallic
# created for new-balance-urainal-black
# created for salomon-pas-normal-studios-rx-snug
# created for hoka-kaha-2-low-gtx-beige
# created for our-legacy-gabe-sneakers-chrome-peak
# created for new-balance-ualgsog-tan
# created for converse-chuck-70-hi-rhubarb-pie-egret-black
# created for converse-chuck-70-hi-tonal-polyester-desert-cargo-egret-black
# created for mizuno-wave-prophecy-ls-black
# created for new-balance-ml610tc-arctic-grey
# created for new-balance-ml610tbe-mindful-grey
# created for converse-chuck-taylor-all-star-construct-hi-vintage-white-black-egret
# created for adidas-craig-green-scuba-stan-white
# created for puma-velophasis-bionic
# created for puma-slipstream-lo-wabi-sabi-white
# created for asics-gel-sonoma-15-50-cream-oatmeal
# created for vans-ua-og-authentic-lx-suede-yellow
# created for vans-ua-og-era-lx-table-scraps-brown
# created for vans-ua-og-authentic-lx-suede-brown
# created for vans-ua-og-sk8-mid-lx-sucv-dkbrn
# created for vans-ua-og-authentic-lx-suede-olive
# created for vans-ua-og-classic-slip-on-denim-indigo
# created for vans-og-slip-on-59-lx-suede-yellow
# created for vans-ua-og-sk8-mid-lx-sucv-mbwwh
# created for vans-ua-og-sk8-mid-lx-sucv-white
# created for vans-ua-og-style-36-lx-coop-vint
# created for vans-ua-og-style-36-lx-coop-beige
# created for vans-ua-og-sk8-hi-lx-tabl-mbrwn
# created for vans-ua-og-sk8-mid-lx-sucv-ltgry
# created for vans-og-slip-on-59-lx-suede-green
# created for vans-ua-og-old-skool-lx-white
# created for vans-og-slip-on-59-lx-suede-brown
# created for vans-sk8-hi-wp-vr3-lx-white
# created for salomon-jungle-ultra-low-advanced-dull-go
# created for salomon-xt-6-cathay-spice-quar-rose-cloud
# created for salomon-acs-pro-white-vanilla-ice-lunroc
# created for salomon-rx-moc-3-0-rubber-taffy-granada-sky
# created for salomon-speedverse-prg-black-alloy-black
# created for salomon-xt-4-og-fiery-red-black-yellow
# created for y-3-gazelle-off-white
# created for new-balance-m2002rsc-sandstone
# created for new-balance-bbw550ba-white
# created for new-balance-bbw550bc-white
# created for asics-gel-nimbus-9-obsidian-grey-moonrock
# created for asics-gel-sonoma-15-50-coffee-desert-camp
# created for asics-gel-1130-white
# created for new-balance-mt580rca-white
# created for new-balance-ml610tbf-aluminum
# created for new-balance-ml610td-classic-crimson
# created for new-balance-mt580rtb-mahogany
# created for new-balance-urc30ag-castlerock
# created for new-balance-ml610tbh-dark-moss
# created for adidas-superstar-82-white-black
# created for adidas-samba-og-black-white-gum
# created for adidas-adimatic-blue
# created for adidas-stan-smith-80s-black
# created for adidas-response-cl-grey
# created for adidas-astir-sn-grey
# created for adidas-astir-sn-white
# created for new-balance-mr530ch-blue
# created for patta-converse-four-leaf-clover-one-star-pro
# created for adidas-stan-smith-recon-white
# created for adidas-superstar-82-white-beige
# created for adidas-xare-boost-green
# created for adidas-xare-boost-white
# created for new-balance-m1906rv-titanium
# created for new-balance-mr530aa-beige
# created for new-balance-mr530cb-grey-matter
# created for new-balance-m1906rw-mindful-grey
# created for new-balance-bb550vtb-sea-salt
# created for new-balance-m1906rob-tobacco
# created for new-balance-mr530ce-sea-salt
# created for new-balance-bb550vta-sea-salt
# created for new-balance-bb650rcf-white
# created for new-balance-bb650rcg-white
# created for new-balance-m2002rve-sea-salt
# created for new-balance-m2002rvd-sea-salt
# created for new-balance-m2002rsb-concrete
# created for adidas-craig-green-scuba-stan-black
# created for asics-gel-trabuco-terra-sps-white
# created for asics-gel-trabuco-terra-sps-midnight-grey
# created for new-balance-m-990-gl5-grey
# created for asics-gel-venture-6-white
# created for asics-gel-trabuco-terra-sps-beige
# created for diesel-s-prototype-cr-sneakers-green
# created for diesel-s-prototype-low-sneakers-white
# created for hoka-mafate-speed-2-cyclamen-all-aboard
# created for hoka-huaka-origins-multi
# created for hoka-kaha-2-gtx-beige
# created for merrell-moab-retro-slide-1trl-birch
# created for asics-gel-trabuco-terra-sps-grey
# created for moncler-trailgrip-low-top-sneakers-green
# created for moncler-trailgrip-low-top-sneakers-fluo-green
# created for moncler-trailgrip-low-top-sneakers-bunt
# created for moncler-trailgrip-gtx-low-top-sneakers-black
# created for new-balance-m990gr1-grey
# created for new-balance-mt580ac2-olive-leaf
# created for new-balance-urainog-brown
# created for new-balance-m990gy2-grey
# created for new-balance-m990py2-purple
# created for new-balance-mt580ab2-workwear
# created for new-balance-urainad-raincloud
# created for mizuno-wave-mujin-tl-gtx-indigo
# created for new-balance-urainaa-tan
# created for new-balance-m1500gbi-brown
# created for on-cloudaway-black-rock
# created for stepney-workers-club-dellow-s-strike-suede-tan
# created for on-cloudwander-waterproof-black-eclipse
# created for on-cloudrock-2-waterproof-black-eclipse
# created for converse-fucking-awesome-louie-lopez-mid-cyan-tint-black
# created for asics-a-p-c-gel-sonoma-15-50-black
# created for new-balance-610v1-grey
# created for new-balance-610v1-truffle
# created for new-balance-rainier-eclipse
# created for new-balance-rainier-turtledove
# created for new-balance-650r-black
# created for converse-drkshdw-turbodrk-chuck-70-white-black-egret
# created for reebok-eames-classic-leather-sand
# created for reebok-club-c-grounds-white
# created for reebok-lt-court
# created for reebok-premier-road-plus-vi-beige
# created for reebok-lt-court-beige
# created for reebok-club-c-vibram-white
# created for asics-gel-trabuco-terra-sps-black
# created for asics-gel-quantum-360-vii-kiso-brown
# created for adidas-orketro-green-black-aluminum
# created for merrell-moab-retro-slide-1trl-black
# created for roa-slip-on-sneaker-military-taupe
# created for norda-001-ltd-edition-g-graphene-black
# created for norda-001-m-white-gum
# created for norda-ciele-the-001-m-gravel
# created for norda-001-w-white-gum
# created for norda-001-m-labrador-tea
# created for norda-001-m-stealth-black
# created for norda-001-m-ltd-edition-icicle
# created for on-cloudultra-bronze-navy
# created for trussardi-neo-sock-sneaker-black
# created for acne-studios-ballow-high-top-sneakers-olive-green
# created for stone-island-grime-sneaker-white
# created for stone-island-grime-sneaker-orange
# created for stone-island-football-sneaker-burgundy
# created for new-balance-m990ta2-blue
# created for new-balance-ms574tvt-team-cream
# created for new-balance-m1500pgl-grey
# created for new-balance-urc30rd-nb-burgundy
# created for new-balance-m990ai2-orange
# created for new-balance-urc30rc-nightwatch-green
# created for new-balance-urc30rb-macadamia-nut
# created for new-balance-mt580og2-natural-indigo
# created for new-balance-m990ad2-red
# created for new-balance-m990wb2-white
# created for new-balance-mr530put-vibrant-apricot
# created for new-balance-m730inv-grey-navy
# created for new-balance-mr530zel-cosmic-jade
# created for new-balance-mr530dwp-lemonade
# created for salomon-xt-6-gtx-black-ebony-lunar-rock
# created for salomon-quest-4d-gtx-advanced-black
# created for on-cloudultra-vine-meadow
# created for mizuno-wave-daichi-7-gtx-black-iron-gate-mecca-orange
# created for wave-prophecy-ls-chime-khaki-cloud70635
# created for mizuno-wave-prophecy-beta-fallen-rock-harbor-mist
# created for mizuno-wave-prophecy-11-dark-shadow-silver-black
# created for mizuno-wave-prophecy-beta-shade-harbor-mist
# created for adidas-ozelia-grey-carbon
# created for adidas-ozrah-pale-nude-orange-rush
# created for adidas-ozelia-off-white-white
# created for raf-simons-cylon-21-cream-black
# created for veja-berlin-womenss-calf-leather-minotaur-beige
# created for reebok-club-c-85-u-white
# created for reebok-premier-road-plus-vi-grey
# created for reebok-club-c-85-grey
# created for reebok-classic-leather-plus-white
# created for reebok-lt-court-chalk
# created for reebok-classic-leather-black
# created for reebok-floatride-energy-yellow-blue
# created for saucony-shadow-6000-white-dark-grey
# created for saucony-shadow-6000-black
# created for saucony-grid-azura-2000-undyed-beige
# created for kenzo-boke-flower-high-top-sneaker-cream
# created for asics-gel-sonoma-15-50-seafoam-birch
# created for new-balance-m920inv-navy-black
# created for new-balance-m1500inv-grey-black
# created for camper-soc-optic-offwhi-tos-fax-barc-aler-lleng
# created for asics-hs4-s-gel-sonoma-15-50-gtx-spring-bouquet-blue-graphite
# created for norda-001-w-white-grey-women
# created for norda-001-m-black
# created for norda-001-m-white-grey-men
# created for converse-run-star-hike-ox-black-white-gum
# created for converse-chuck-70-hi-black-black-egret
# created for norda-001-m-sulphur
# created for asics-gel-1090-piedmont-gray-tarmac
# created for converse-chuck-70-hi-pink-aura-egret-black
# created for converse-chuck-70-ox-papyrus-egret-black
# created for converse-chuck-70-mule-slip-black-black-egret
# created for new-balance-u574bh2-sea-salt
# created for salomon-x-mission-4-black-ebony-gum
# created for y-3-hicho-grey-cream
# created for converse-golf-le-fleur-chuck-70-ox-owl-camo-egret-corydalis-blue-antique-white
# created for last-resort-ab-vm002-suede-lo-sand-black
# created for soulland-li-ning-furious-rider-6
# created for stepney-workers-club-dellow-track-raw-nylon-grey
# created for stepney-workers-club-dellow-track-ripstop-navy
# created for saucony-original-endorphin-trail
# created for reebok-x-maison-margiela-question-mid-memory-of-black
# created for reebok-x-maison-margiela-question-mid-memory-of-white
# created for reebok-x-maison-margiela-zig-3d-storm-memory-of-white
# created for asics-x-afew-gt-ii-blushchocolate-brown
# created for raf-simons-cylon-21-black-ss22
# created for raf-simons-orion-grey
# created for on-x-highsnobiety-womens-cloudswift-hs-white
# created for puma-x-butter-goods-suede-vtg-whisper-whitepuma-black
# created for puma-x-butter-goods-suede-slipstream-lo-mocha-bisquepuma-blackthyme
# created for converse-one-star-ox-indigoobsidianegret
# created for converse-chuck-70-ox-sunflowerblackegret
# created for vans-anaheim-factory-authentic-44-dx-leopard-camogrape-leaf
# created for converse-chuck-70-hi-lemon-dropegretblack
# created for converse-run-star-motion-ox-whiteblackegret
# created for converse-run-star-motion-ox-blackwhiteegret
# created for converse-chuck-70-utility-hi-whiteegretblack
# created for converse-chuck-70-utility-hi-storm-windegret
# created for converse-chuck-70-ox-parchmentgarnetegret
# created for converse-chuck-70-ox-blackblackegret
# created for converse-chuck-70-mule-slip-egretegretblack
# created for converse-chuck-70-ox-naturalblackegret
# created for maison-margiela-x-reebok-classic-leather-memory-of-blackfootwear-whiteblack
# created for converse-x-golf-wang-chuck-70-ox-python-pink-dogwood-vintage-white
# created for last-resort-ab-vm001-suede-hi-blackwhite
# created for new-balance-xc-72-white
# created for vans-anaheim-factory-authentic-44-dx-vanity-plate-lightblue
# created for vans-anaheim-factory-authentic-44-dx-vanity-plate-plateblack
# created for vans-style-36-decon-sf-green-milieublack
# created for hoka-mafate-speed-2-eggnog-oxford-tan
# created for converse-chuck-70-high-light-silver-pink-clay-egret
# created for maison-margiela-x-reebok-classic-leather-tabi-low-white
# created for salomon-xt-6-white-white-lunar-rock
# created for salomon-xt-6-advanced-wings-black-black-phantom
# created for converse-runstar-hike-high-platform-black-white-gum
# created for converse-run-star-hike-platform-white-black-gum
# created for converse-run-star-motion-platform-black-white-gum-honey
# created for converse-chuck-70-university-blue-egret-black
# created for maison-margiela-replica-paint-drop-sneakers-white
# created for maison-margiela-calfskin-replica-sneakers-light-grey
# created for converse-weapon-cx-mid-egret-light-twine
# created for salomon-xt-wings-2-advanced-peat
# created for converse-x-space-jam-a-new-legacy-chuck-taylor-70-multi
# created for maison-margiela-x-reebok-club-c-trompe-loeil-red
# created for grey-formal-grey-g3-grape
# created for converse-chuck-70-hi-parchment-garnet-egret
# created for new-balance-stone-island-made-in-uk-991v2-black-olive
# created for stone-island-rock-beige-78fws011
# created for converse-cons-alltimers-fastbreak-pro-mid-black
# created for new-balance-m991gl-grey
# created for puma-p-a-m-suede-vintage-brown
# created for on-cloudvista-waterproof-eclipse-black
# created for roa-khatarina-sneaker-sand
# created for on-cloudventure-ice-kelp
# created for on-the-roger-clubhouse-white-indigo

# %%
df = pd.DataFrame(parse_result)
df.to_csv(f"{WEBSITE_NAME}/metadata.csv", index=False)
df.shape
# Out:
# on-the-roger-clubhouse-white-indigo is done
# (590, 10)

# %%
df['right-side-img']
# Out:
# 0      highsnobiety/photos/Salomon/salomon-xt-quest-2...
# 1      highsnobiety/photos/Salomon/salomon-acs-pro-pe...
# 2      highsnobiety/photos/Adidas/adidas-gazelle-core...
# 3      highsnobiety/photos/Converse/converse-one-star...
# 4      highsnobiety/photos/Saucony/saucony-progrid-tr...
#                              ...
# 585    highsnobiety/photos/Puma x P.A.M./puma-p-a-m-s...
# 586    highsnobiety/photos/On/on-cloudvista-waterproo...
# 587    highsnobiety/photos/ROA/roa-khatarina-sneaker-...
# 588    highsnobiety/photos/On/on-cloudventure-ice-kel...
# 589    highsnobiety/photos/On/on-the-roger-clubhouse-...
# Name: right-side-img, Length: 590, dtype: object
